# %% [markdown]
# Download caltech-101 dataset

# %%
import kagglehub
import shutil
import os

# Download dataset (by default into kagglehub cache directory)
path = kagglehub.dataset_download("imbikramsaha/caltech-101")

# Get current working directory (where the notebook is located)
current_dir = os.getcwd()

# Define target directory inside the current notebook folder
target_dir = os.path.join(current_dir, "caltech-101")

# Move dataset from kagglehub cache to the notebook directory
shutil.move(os.path.join(path, "caltech-101"), target_dir)

# Remove existing target directory if it already exists
if os.path.exists(path):
    shutil.rmtree(path)

print("Dataset moved to:", target_dir)
# Out:
# ...
# 100%|██████████| 131M/131M [00:11<00:00, 11.8MB/s]
# Extracting files...
# Dataset moved to: e:\KLTN\src\XAI\codes\data\caltech-101

# %% [markdown]
# Download animals dataset

# %%
import kagglehub
import shutil
import os
# Download latest version
path = kagglehub.dataset_download("iamsouravbanerjee/animal-image-dataset-90-different-animals")

print("Path to dataset files:", path)

current_dir = os.getcwd()

# Define target directory inside the current notebook folder
target_dir = os.path.join(current_dir, "animals")

# Move dataset from kagglehub cache to the notebook directory
shutil.move(os.path.join(path, "animals/animals"), target_dir)

# Remove existing target directory if it already exists
if os.path.exists(path):
    shutil.rmtree(path)
# Out:
# ...
# 100%|██████████| 656M/656M [00:55<00:00, 12.4MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Hoang Bao Khanh\.cache\kagglehub\datasets\iamsouravbanerjee\animal-image-dataset-90-different-animals\versions\5

# %% [markdown]
# Download SARS-COV2-CT dataset

# %%
import os

folder_path = r'E:\\KLTN\\src\\XAI\\codes\\data\\caltech-101'

print(len(os.listdir(folder_path)))
# Out:
# 102

# %% [markdown]
# Download Brain Tumor dataset

# %%
import kagglehub
import os
import shutil

# Download latest version
path = kagglehub.dataset_download("masoudnickparvar/brain-tumor-mri-dataset")

print("Path to dataset files:", path)

current_dir = os.getcwd()

target_dir = os.path.join(current_dir, "brain-tumor")

# Move dataset from kagglehub cache to the notebook directory
for folder_name in os.listdir(path):
    # print(folder_name)
    folder_path = os.path.join(target_dir, folder_name)
    #os.makedirs(folder_path, exist_ok=True)
    shutil.move(os.path.join(path, folder_name), folder_path)

# Remove existing target directory if it already exists
if os.path.exists(path):
    shutil.rmtree(path)
# Out:
# ...
# 100%|██████████| 149M/149M [00:06<00:00, 23.2MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Hoang Bao Khanh\.cache\kagglehub\datasets\masoudnickparvar\brain-tumor-mri-dataset\versions\1
